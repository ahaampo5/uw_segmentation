# %%
import segmentation_models.segmentation_models_pytorch as smp

# %%
import timm

# %%
timm.create_model('efficientnet_b3')
# Out:
# EfficientNet(
#   (conv_stem): Conv2d(3, 40, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act1): SiLU(inplace=True)
#   (blocks): Sequential(
#     (0): Sequential(
#       (0): DepthwiseSeparableConv(
#         (conv_dw): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#         (bn1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(40, 10, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(10, 40, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pw): Conv2d(40, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
m = smp.Unet(encoder_name='efficientnet-b3')

# %%
m.encoder._blocks[0]
# Out:
# MBConvBlock(
#   (_depthwise_conv): Conv2dStaticSamePadding(
#     40, 40, kernel_size=(3, 3), stride=[1, 1], groups=40, bias=False
#     (static_padding): ZeroPad2d((1, 1, 1, 1))
#   )
#   (_bn1): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_se_reduce): Conv2dStaticSamePadding(
#     40, 10, kernel_size=(1, 1), stride=(1, 1)
#     (static_padding): Identity()
#   )
#   (_se_expand): Conv2dStaticSamePadding(
#     10, 40, kernel_size=(1, 1), stride=(1, 1)
#     (static_padding): Identity()
#   )
#   (_project_conv): Conv2dStaticSamePadding(
#     40, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#     (static_padding): Identity()
#   )
#   (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_swish): MemoryEfficientSwish()
# )

# %%
import yaml

# %%
# !ls configs
# Out:
# unet-efficient-b3.yaml

# %%
with open('configs/unet-efficient-b3.yaml', 'r') as f:
    tmp = yaml.load(f, yaml.FullLoader)

# %%
yaml.FullLoader
# Out:
# yaml.loader.FullLoader

# %%
tmp
# Out:
# {'seed': 101,
#  'debug': False,
#  'exp_name': '2.5D',
#  'comment': 'unet-efficientnet-b3-384x384',
#  'model_name': 'Unet',
#  'backbone': 'efficientnet-b3',
#  'batch_size': 64,
#  'img_size': [384, 384],
#  'epochs': 15,
#  'lr': 0.002,
#  'scheduler': 'CosineAnnealingLR',
#  'min_lr': 1e-07,
#  'T_max': 'int(30000/train_bs*epochs)+50',
#  'T_0': 25,
#  'warmup_epochs': 0,
#  'wd': 1e-06,
#  'n_accumulate': 1,
#  'n_fold': 5,
#  'folds': [0, 1],
#  'num_classes': 3,
#  'device': 'cuda:0',
#  'data_root': '/tmp/images/*'}

# %%
from glob import glob
import matplotlib.pyplot as plt
import numpy as np

# %%
for idx, i in enumerate(sorted(glob('/tmp/images/*'))):
    img = np.load(i)
    mx = img.max()
    print(mx)
    img = img / mx
    plt.imshow(img)
    plt.show()
    if idx == 5:
        break
# Out:
# 140
# 147
# 145
# 148
# 156
# 163
